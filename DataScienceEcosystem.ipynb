# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
#
# * Enumerate main languages in data science
# * Describe most commonly used libraries
# * Giving examples for using markdown and code cells in jupyter
# * Identify some uses of markdown cells, such as tables, ordered and unordered lists

# %% [markdown]
# Some of the popular languages that Data Scientists use are:\
# \
# 1.-Pyhton\
# 2.-R\
# 3.-Ruby\
# 4.-Matlab\
# 5.-Julia\
# 6.-Scala\
# 7.-SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:\
# 1.-NumPy\
# 2.-Pandas\
# 3.-Matplotlib\
# 4.-Seaborn\
# \
# Machine Learning\
# \
# 5.-Scikit-learn\
# 6.-XGBoost / LightGBM\
# \
# Deep Learning\
# \
# 7.-Plotly\
# 8.-TensorFlow / Keras

# %% [markdown]
# |Data Science Tools|
# |:--------:|
# | Jupyter Notebook/JupyterLab  |
# | RStudio  |
# |  VS Code |

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
a=(3*4)+5
print(a)
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Juan Pablo Jiménez Cervantes
